# %%
import pandas as pnd

# %%
# Downloading the benchmark file using pandas library
benchmark_file = pnd.read_csv("HGVS_2020_big_benchmark.tsv", sep="\t")

# %%
# Printing benchmark file read with pandas
print(benchmark_file)
print("length of the benchmark_file:",len(benchmark_file))
# Out:
#                              # ID       Label
# 0      NC_000016.10:g.89748658C>T  Pathogenic
# 1     NC_000008.11:g.143818378G>A  Pathogenic
# 2      NC_000023.11:g.32644238T>A      Benign
# 3      NC_000002.12:g.39022779A>G  Pathogenic
# 4     NC_000001.11:g.154926384G>A  Pathogenic
# ...                           ...         ...
# 5995   NC_000012.12:g.88125363G>A  Pathogenic
# 5996   NC_000009.12:g.92715372T>C      Benign
# 5997    NC_000017.11:g.3554778T>C      Benign
# 5998   NC_000017.11:g.37686988T>C      Benign
# 5999   NC_000017.11:g.18122113G>T  Pathogenic
#
# [6000 rows x 2 columns]
# length of the benchmark_file: 6000

# %%
# For counting of "Pathogenic and Benign" using pandas
benign_count = 0
pathogenic_count = 0

for row in range(len(benchmark_file)):
    value = benchmark_file.iloc[row,1]

    if value == "Benign":
        benign_count += 1
    elif value == "Pathogenic":
        pathogenic_count += 1

print(f"\nBenign: {benign_count}")
print(f"\nPathogenic: {pathogenic_count}")
# Out:
# Benign: 3000
#
# Pathogenic: 3000
